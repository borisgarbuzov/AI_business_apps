# %%
import numpy as np
x = np.array([1, 2, 3])
y = (x == 2)
y
# Out:
# array([False,  True, False])

# %%
x1 = np.array([[1, 2, 3], [4, 5, 6]])
x2 = x1.copy()
x1
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
np.vstack([x1, x2])
# Out:
# array([[1, 2, 3],
#        [4, 5, 6],
#        [1, 2, 3],
#        [4, 5, 6]])

# %%
np.hstack([x1, x2])
# Out:
# array([[1, 2, 3, 1, 2, 3],
#        [4, 5, 6, 4, 5, 6]])
