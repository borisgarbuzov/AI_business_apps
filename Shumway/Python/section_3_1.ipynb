# %%
# !pip install astsadata statsmodels --upgrade
# Out:
# Collecting astsadata
#   Downloading https://files.pythonhosted.org/packages/ab/e6/08e5f6a210b89f37f0f76389aa3e88935da207fff966c097627653b20569/astsadata-0.0.4-py3-none-any.whl (473kB)
#      |████████████████████████████████| 481kB 7.0MB/s
# Collecting statsmodels
#   Downloading https://files.pythonhosted.org/packages/da/69/8eef30a6237c54f3c0b524140e2975f4b1eea3489b45eb3339574fc8acee/statsmodels-0.12.2-cp37-cp37m-manylinux1_x86_64.whl (9.5MB)
#      |████████████████████████████████| 9.5MB 8.7MB/s
# Requirement already satisfied, skipping upgrade: pandas in /usr/local/lib/python3.7/dist-packages (from astsadata) (1.1.5)
# Requirement already satisfied, skipping upgrade: scipy>=1.1 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.4.1)
# Requirement already satisfied, skipping upgrade: patsy>=0.5 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (0.5.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.19.5)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->astsadata) (2.8.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->astsadata) (2018.9)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5->statsmodels) (1.15.0)
# Installing collected packages: astsadata, statsmodels
#   Found existing installation: statsmodels 0.10.2
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
# Successfully installed astsadata-0.0.4 statsmodels-0.12.2

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.tsa as tsm
import matplotlib.pyplot as plt
from astsadata import *
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/arrays/datetimes.py:1092: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   UserWarning,

# %% [markdown]
# # Section 3.1 Autoregressive Moving Average Models

# %%
# Example 3.2
fig, axes = plt.subplots(nrows=2, figsize=(7, 5))
axes[0].plot(sm.tsa.arma_generate_sample(ar=[1, -.9], ma=[1, 0], nsample=100))
axes[0].set_xlabel("Time")
axes[0].set_title(r"AR(1) $\phi = +0.9$")
axes[1].plot(sm.tsa.arma_generate_sample(ar=[1, .9], ma=[1, 0], nsample=100))
axes[1].set_xlabel("Time")
axes[1].set_title(r"AR(1) $\phi = -0.9$")
fig.tight_layout()
plt.show()

# %%
# Example 3.5
fig, axes = plt.subplots(nrows=2, figsize=(7, 5))
axes[0].plot(sm.tsa.arma_generate_sample(ar=[1, 0], ma=[1, .9], nsample=100))
axes[0].set_xlabel("Time")
axes[0].set_title(r"MA(1) $\theta = +0.9$")
axes[1].plot(sm.tsa.arma_generate_sample(ar=[1, 0], ma=[1, -.9], nsample=100))
axes[1].set_xlabel("Time")
axes[1].set_title(r"MA(1) $\theta = -0.9$")
fig.tight_layout()
plt.show()

# %%
# Example 3.7
np.random.seed(8675309) # Jenny, I got your number
x = np.random.normal(loc=5, size=15000) # Jenerate iid N(5, 1)s

mod = sm.tsa.arima.ARIMA(x, order=(1, 0, 1), enforce_invertibility=False, enforce_stationarity=False)
res = mod.fit()
print(res.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                15000
# Model:                 ARIMA(1, 0, 1)   Log Likelihood              -21281.889
# Date:                Fri, 14 May 2021   AIC                          42571.778
# Time:                        06:18:42   BIC                          42602.241
# Sample:                             0   HQIC                         42581.885
#                               - 15000
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.9981      0.008    622.139      0.000       4.982       5.014
# ar.L1          0.4020      0.585      0.687      0.492      -0.745       1.549
# ma.L1         -0.4118      0.583     -0.707      0.480      -1.554       0.730
# sigma2         1.0001      0.012     85.453      0.000       0.977       1.023
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 3.06
# Prob(Q):                              0.95   Prob(JB):                         0.22
# Heteroskedasticity (H):               1.01   Skew:                            -0.02
# Prob(H) (two-sided):                  0.79   Kurtosis:                         2.95
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Example 3.8
# leads=11 instead of 10, because Python, unlike R, prints zero-indexed coefficient too
print(tsm.arima_process.arma2ma(ar=[1, -.9], ma=[1, .5], lags=11))
print(tsm.arima_process.arma2ma(ar=[1, .5], ma=[1, -.9], lags=11))
# Out:
# [1.         1.4        1.26       1.134      1.0206     0.91854
#  0.826686   0.7440174  0.66961566 0.60265409 0.54238868]
# [ 1.         -1.4         0.7        -0.35        0.175      -0.0875
#   0.04375    -0.021875    0.0109375  -0.00546875  0.00273437]
