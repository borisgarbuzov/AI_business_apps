# %%
# !git clone https://github.com/dreamvrutik/Machine-Learning-A1.git
# Out:
# Cloning into 'Machine-Learning-A1'...
# remote: Enumerating objects: 63, done.
# remote: Counting objects: 100% (63/63), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 63 (delta 27), reused 35 (delta 10), pack-reused 0
# Unpacking objects: 100% (63/63), done.

# %%
# !ls
# Out:
# Machine-Learning-A1  sample_data

# %%
# %cd \Machine-Learning-A1
# Out:
# /content/Machine-Learning-A1

# %%
# !ls
# Out:
#  a1_d1.csv		  New_data.csv
#  a1_d2.csv		  normal_distribution_a1_d1.csv.png
#  a1_d3.txt		  normal_distribution_a1_d2.csv.png
#  fischer.py		  README.md
#  LICENSE		  sentiment_analysis_NaiveBayes.py
# 'ML-A1 doc.pdf'		  Tranformed_plot_a1_d1.csv.png
#  naive_bayes_result.PNG   Tranformed_plot_a1_d2.csv.png

# %%
# !python fischer.py a1_d1.csv
# Out:
# Threshhold after transformation =  0.15207088287130205
# Accuracy =  0.993
# F1-Score =  0.9929929929929929

# %%
# !rm *.png
